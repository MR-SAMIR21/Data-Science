# %%
# print is use for answer

# %%
a=10
b=20
a
b
# Out:
# 20

# %%
a=10
b=20
print(a)
print(b)
# Out:
# 10
# 20

# %%
print(10)
print(10,20)
print('python')
print(10,20,'python')
# Out:
# 10
# 10 20
# python
# 10 20 python

# %%
num1=20
num2=30
add=num1+num2
print(add)
# Out:
# 50

# %% [markdown]
# # Print Result with String

# %%
num1=20
num2=30
add=num1+num2
print('The addition of ',num1,'and', num2, 'is=',add)
# Out:
# The addition of  20 and 30 is= 50

# %%
name='Python'
age=20
city='hyd'
# hellow my name is python and i am 10 year old from hydrabad
print('My name is ', name,'and i am ',age, 'years old from',city)
# Out:
# My name is  Python and i am  20 years old from hyd

# %%
print('My name is ', name,'and i am ',age, 'years old from',city)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_14897/3075212813.py in <cell line: 0>()
# ----> 1 print('My name is ', name,'and i am ',age, 'years old from',city)
#
# NameError: name 'name' is not defined

# %% [markdown]
# # Print Format Method

# %%
num1=20
num2=30
add=num1+num2
print('The addition of {} and {} is = {}'. format (num1, num2,add))
# Out:
# The addition of 20 and 30 is = 50

# %%
name='Python'
age=20
city='hyd'
# hellow my name is python and i am 10 year old from hydrabad

# %%
print('Hello My name is {}, and i am {} years old from {}'.format(name,age,city))
# Out:
# Hello My name is Python, and i am 20 years old from hyd

# %%
num1=100
num2=25
num3=333
avg=(num1+num2+num3)/3  # or we can use avg=round(num1+num2+num3)/3,2
avg1=round(num1+num2+num3)/3,2

#The avrage of num1, num2, num3 is = avg
print('The avrage of {} , {}, and {} is = {} or {}, '.format(num1,num2,num3,avg, avg1))
# Out:
# The avrage of 100 , 25, and 333 is = 152.66666666666666 or (152.66666666666666, 2),

# %% [markdown]
# # More short format meythod(f string method)

# %%
num1=20
num2=30
add=num1+num2
print(f'The addition of {num1} and {num2} is = {add}') # alwayes prefer this
# Out:
# The addition of 20 and 30 is = 50

# %%
name='Python'
age=20
city='hyd'
# Hellow my name is python and i an 10 years old from hyd

# %%
print(f'hellow my name is {name}, and i am {age} year old, from {city}.')
# Out:
# hellow my name is Python, and i am 20 year old, from hyd.

# %%
num1=100
num2=25
num3=333
avg=round((num1+num2+num3)/3,2)  #or we can use avg=round(num1+num2+num3)/3,2
#The average of num1 , num2, num3 is = avg

# %%
print(f'The average of{num1}, {num2},{num3} is = {avg}')
# Out:
# The average of20, 30,333 is = 152.66666666666666

# %%
#Lete combine all
num1=20
num2=30
add=num1+num2
print('The addition of ',num1,'and',num2 ,'is = ',add)

print('The addition of {} and {} is = {}'.format(num1, num2,add) )

print(f'The addition of {num1} and{num2} is = {add}')
# Out:
# The addition of  20 and 30 is =  50
# The addition of 20 and 30 is = 50
# The addition of 20 and30 is = 50

# %% [markdown]
# # **End Statement**

# %%
print ('hello') # 1st statement
print('Good Morning')  # 2nd Statement
# i want print like :- hello Good Morning
# Out:
# hello
# Good Morning

# %%
print('hello', end=' ')  #1st statement
print ('world good day')  # 2nd statement
# Out:
# hello world good day

# %% [markdown]
# # Seprator

# %%
print('hello', 'hai', 'how are you', sep='--->')
# Out:
# hello--->hai--->how are you

# %%
print('hello', 'hai', 'how are you', sep='&')
# Out:
# hello&hai&how are you

# %%
print('hello', 'hai', 'how are you', sep='@')
# Out:
# hello@hai@how are you

# %%
print('hello', 'hai', 'how are you', sep=' ')
# Out:
# hello hai how are you

# %%
print(3,'.')  # . is far from 3 so here we will use sep method
# Out:
# 3 .

# %%
print(3,'.', sep='')  # see now space setteld(also use to remove space B/W word)
# Out:
# 3.

# %%
print(1,2,end=' ')
print(3,'.',sep='')
# will print 1 2 3
# Out:
# 1 2 3.
