# %% [markdown]
# # **String**

# %%
p = 20
q = 20
r = 20

# %%
p = q = r = 20

# %%
print(id(p))
print(id(q))
print(id(r))
# Out:
# 11645960
# 11645960
# 11645960

# %%
p1,q1,r1 = 20
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_572/3518222509.py in <cell line: 0>()
# ----> 1 p1,q1,r1 = 20
#
# TypeError: cannot unpack non-iterable int object

# %%
p1,q1,r1 = 20, 25, 30

# %%
print(id(p1))
print(id(q1))
print(id(r1))
# Out:
# 11645960
# 11646120
# 11646280

# %% [markdown]
# # **String**

# %%
s = "Hello Python"
s
# Out:
# 'Hello Python'

# %%
len(s)
# Out:
# 12

# %%
s[0]  # forward indexing
# Out:
# 'H'

# %%
s[-1] # backward indexing
# Out:
# 'n'

# %%
s[:]
# Out:
# 'Hello Python'

# %%
s
# Out:
# 'Hello Python'

# %%
s[11]
# Out:
# 'n'

# %%
s[0:5]
# Out:
# 'Hello'

# %%
s[6:9]
# Out:
# 'Pyt'

# %%
s[-5:-1]
# Out:
# 'ytho'

# %%
s = "Hello Python"
s
# Out:
# 'Hello Python'

# %%
s
# Out:
# 'Hello Python'

# %%
s[2:]
# Out:
# 'llo Python'

# %%
s
# Out:
# 'Hello Python'

# %%
s[:6]
# Out:
# 'Hello '

# %%
s
# Out:
# 'Hello Python'

# %%
s[::-1]
# Out:
# 'nohtyP olleH'

# %%
s[0:10:5]
# Out:
# 'H '

# %%
s1 = 'nareshit'
s1
# Out:
# 'nareshit'

# %%
s1[0:10]
# Out:
# 'nareshit'
