# %% [markdown]
# <a href="https://colab.research.google.com/github/MR-SAMIR21/Data-Science/blob/main/Task_5_TUPLE_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Tuple Creation**

# %%
tup1 = () # Empty tuple

# %%
tup2 = (10,30,60)  # tuple of integers numbers

# %%
tub3 = (10.77,30.66,60.88)  # tuple of float numbers

# %%
tup4 = ('one','two',"three")  # tuple of string

# %%
tup5 = ('Samir',35, (50,100), (150, 90))  # Nested tuples

# %%
tup6 = (100, 'samir', 17.765)  # Tuple of mixed data types

# %%
tup7 = ('Samir', 25, [50, 100], [150, 90], {'John', 'David'} , (99,22,33))

# %%
len(tup7) # length of list
# Out:
# 6

# %% [markdown]
# # **Tuple Indexing**

# %%
tup2[0]  # Retrive first element of the tuple
# Out:
# 10

# %%
tup4[0] # Retrive first element of the tuple
# Out:
# 'one'

# %%
tup4[0][0]  # Nested indexing - Access the first chacter of the first tuple element
# Out:
# 'o'

# %%
tup4[-1] #Last item of the tuple
# Out:
# 'three'

# %% [markdown]
# # **Tuple Slicing**

# %%
mytuple = ('one' , 'two', 'three', 'four', 'five', 'six', 'seven', 'eight')

# %%
mytuple[0:3]  # Return all items from 0th to 3rd index location excluding the item
# Out:
# ('one', 'two', 'three')

# %%
mytuple[2:5]  # List all items from 2nd to 5th index location excluding the item

# %%
mytuple[:3]  # Return first three item
# Out:
# ('one', 'two', 'three')

# %%
mytuple[:2]  # Return first two item
# Out:
# ('one', 'two')

# %%
mytuple[-3:]  # Return last Three items
# Out:
# ('six', 'seven', 'eight')

# %%
mytuple[-2:]  # Return last Two items
# Out:
# ('seven', 'eight')

# %%
mytuple[-1]  # Return last  items of the tuple

# %%
mytuple[:]  # Return whole tuple
# Out:
# ('one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight')

# %% [markdown]
# # **Remove & Changes Items**

# %%
mytuple
# Out:
# ('one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight')

# %%
del mytuple[0]  # Tuples are immutable which means we can't DELETE tuple items
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_391/1004790074.py in <cell line: 0>()
# ----> 1 del mytuple[0]
#
# TypeError: 'tuple' object doesn't support item deletion

# %%
mytuple[0] = 1  # Tuples are immutable which means we can't CHANGE tule items
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_391/2453735110.py in <cell line: 0>()
# ----> 1 mytuple[0] = 1
#
# TypeError: 'tuple' object does not support item assignment

# %%
del mytuple  # Deleting entires tuple object is possible

# %% [markdown]
# # **Loop Through a tuple**

# %%
mytuple = ('one' , 'two', 'three', 'four', 'five', 'six', 'seven', 'eight')

# %%
mytuple
# Out:
# ('one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight')

# %%
for i in mytuple:
  print(i)
# Out:
# one
# two
# three
# four
# five
# six
# seven
# eight

# %%
for i in enumerate(mytuple):
  print(i)
# Out:
# (0, 'one')
# (1, 'two')
# (2, 'three')
# (3, 'four')
# (4, 'five')
# (5, 'six')
# (6, 'seven')
# (7, 'eight')

# %% [markdown]
# # **Tuple Membership**

# %%
mytuple
# Out:
# ('one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight')

# %%
'one' in mytuple  # Check if 'One' exist in the list
# Out:
# True

# %%
'ten' in mytuple  # Check if 'three' exist in the list
# Out:
# False

# %%
if 'three' in mytuple:   # Check if 'three' exist in the list
  print('Three is presentin the tuple')
else:
  print('Three is not present in the tuple')
# Out:
# Three is presentin the tuple

# %%
if 'eleven' in mytuple:   # Check if 'eleven' exist in the list
  print('eleven is presentin the tuple')
else:
  print('eleven is not present in the tuple')
# Out:
# eleven is not present in the tuple

# %% [markdown]
# # **Index Position**

# %%
mytuple
# Out:
# ('one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight')

# %%
mytuple.index('one')  # Index of first element equal to 'one'
# Out:
# 0

# %%
mytuple.index('five')  # Index of first element equal to 'five'
# Out:
# 4

# %% [markdown]
# # **Sorting**

# %%
mytuple2 = (43,67,12,99,6,90,67)

# %%
sorted(mytuple2) # Returns a new sorted list and doesn't changes original tuple
# Out:
# [6, 12, 43, 67, 67, 90, 99]

# %%
sorted(mytuple2, reverse=True) # Sort in Descending order
# Out:
# [99, 90, 67, 67, 43, 12, 6]
