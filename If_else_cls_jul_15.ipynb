# %% [markdown]
# <a href="https://colab.research.google.com/github/MR-SAMIR21/Data-Science/blob/main/If_else_cls_jul_15.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
if True:
 print("hello")
# Out:
# hello

# %%
if True:
print('hello')
# Out:
#   File "/tmp/ipykernel_523/1785633973.py", line 2
#     print('hello')
#     ^
# IndentationError: expected an indented block after 'if' statement on line 1

# %%
if True:
  print('hello')

print('how are you')
# Out:
# hello
# how are you

# %%
if True:
  print('hello')

# %%
if False:
  print('bye')

# %%
if False:
  print('hello')

print('how are you')
# Out:
# how are you

# %%
if True:
  print('Data Science')

print('bye for now')
# Out:
# Data Science
# bye for now

# %%
if False:
  print('Data Science')

print('bye for now')
# Out:
# bye for now

# %%
if True:
  print('Data Science')

else:
  print('bye for now')
# Out:
# Data Science

# %%
if False:
  print('Data Science')

else:
  print('bye for now')
# Out:
# bye for now

# %% [markdown]
# # write python code to check weather number is even or odd

# %%
x = 4

r = x % 2

if r == 0:
  print('Even num')
# Out:
# Even num

# %%
x = 6

r = x % 2

if r == 0:
  print('Even num')

if r ==1:
  print('Odd num')
# Out:
# Even num

# %%
x = 6

r = x % 2

if r == 0:
  print('Even num')

else:
  print('Odd num')
# Out:
# Even num

# %%
x = 6

r = x % 2

if r == 0:
  print('Even num')

print('Odd num')
# Out:
# Even num
# Odd num

# %%
x = 6

r = x % 2

if r == 0:print('Even num')

else:print('Odd num')
# Out:
# Even num

# %%
x = 6

r = x % 2

if r == 0:    print('Even num')

else:   print('Odd num')
# Out:
# Even num

# %%
x = 10

r = x % 2

if r == 0:
  print('Even num')

if r!=0:
  print('Odd num')
# Out:
# Even num

# %% [markdown]
# # Nested if

# %%
x = 4
r = x % 2

if r==0:
  print('Even number')
  if x>5:
    print('greater number')
  else:
    print('smaller number')
else:
  print('Odd Number')
# Out:
# Even number
# smaller number

# %% [markdown]
# # if elif

# %%
x = 1

if x ==1:
  print('one')
elif x == 2:
  print('two')
elif x == 3:
  print('three')
elif x == 4:
  print('four')
# Out:
# one

# %%
x = 10

if x ==1:
  print('one')
elif x == 2:
  print('two')
elif x == 3:
  print('three')
elif x == 4:
  print('four')

else:
  print('number not found')
# Out:
# number not found

# %%
num = int(input("Enter a number: "))

if num > 0:
  print('Positive Number')
elif num < 0:
  print('Negateive')
else :
  print('Zero ')
# Out:
# Enter a number: -5
# Negateive
