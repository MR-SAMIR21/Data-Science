# %% [markdown]
# # **Python type casting or type conversion**

# %%
int(2.3)
# Out:
# 2

# %%
int(2.3, 4.5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_2129/648743742.py in <cell line: 0>()
# ----> 1 int(2.3, 4.5)
#
# TypeError: 'float' object cannot be interpreted as an integer

# %%
int(True)
# Out:
# 1

# %%
int(False)
# Out:
# 0

# %%
int(True, False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_2129/662574807.py in <cell line: 0>()
# ----> 1 int(True, False)
#
# TypeError: int() can't convert non-string with explicit base

# %%
int(true)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2129/1400295557.py in <cell line: 0>()
# ----> 1 int(true)
#
# NameError: name 'true' is not defined

# %%
print(int(2.3))  # float - int
print(int(True)) # bool - int
print(int('10'))  # string - int
print(int(1+2j))  #complex - int not possible
# Out:
# 2
# 1
# 10
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_2129/1836532314.py in <cell line: 0>()
#       2 print(int(True)) # bool - int
#       3 print(int('10'))  # string - int
# ----> 4 print(int(1+2j))  #complex - int
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'complex'

# %%
int('one')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_2129/2369944164.py in <cell line: 0>()
# ----> 1 int('one')
#
# ValueError: invalid literal for int() with base 10: 'one'

# %%
int('1')
# Out:
# 1

# %%
print(float(2))
# Out:
# 2.0

# %%
print(float(False))
# Out:
# 0.0

# %%
print(float(2 + 3j))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_2129/3453082960.py in <cell line: 0>()
# ----> 1 print(float(2 + 3j))
#
# TypeError: float() argument must be a string or a real number, not 'complex'

# %%
print(float('two'))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_2129/4242820796.py in <cell line: 0>()
# ----> 1 print(float('two'))
#
# ValueError: could not convert string to float: 'two'

# %%
print(float('2'))
# Out:
# 2.0

# %%
complex(10)
# Out:
# (10+0j)

# %%
complex(10, 20)
# Out:
# (10+20j)

# %%
complex(10,20, 30)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_2129/1835725810.py in <cell line: 0>()
# ----> 1 complex(10,20, 30)
#
# TypeError: complex() takes at most 2 arguments (3 given)

# %%
complex(2.3, 5.)
# Out:
# (2.3+5j)

# %%
complex(5, 2.3)
# Out:
# (5+2.3j)

# %%
complex(False, False)
# Out:
# 0j

# %%
complex('1', 23)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_2129/1381951277.py in <cell line: 0>()
# ----> 1 complex('1', 23)
#
# TypeError: complex() can't take second arg if first is a string

# %%
complex( 23,'1')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_2129/3355459111.py in <cell line: 0>()
# ----> 1 complex( 23,'1')
#
# TypeError: complex() second arg can't be a string

# %%
complex('1')
# Out:
# (1+0j)

# %%
print(bool(1))
print(bool(1.1))
print(bool(1+2j))
print(bool('nit'))
# Out:
# True
# True
# True
# True

# %%
bool(  )
# Out:
# False

# %%
str(2)
# Out:
# '2'

# %%
str(2.2)
# Out:
# '2.2'

# %%
str(True)
# Out:
# 'True'

# %%
str(1+2j)
# Out:
# '(1+2j)'
