# %%
import sys
import keyword
import operator
from datetime import datetime
import os

# %%
print(keyword.kwlist)   # List all Python keywords
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
len(keyword.kwlist) # Python contains 35 keywords
# Out:
# 35

# %% [markdown]
# # **Identifiers**

# %%
1var = 10  # Identifier can't start with a digit
# Out:
#   File "/tmp/ipykernel_8108/2479297364.py", line 1
#     1var = 10  # Identifier can't start with a digit
#     ^
# SyntaxError: invalid decimal literal

# %%
val2@ = 35  # Indentifier can't use special symbols
# Out:
#   File "/tmp/ipykernel_8108/3228573148.py", line 1
#     val2@ = 35  # Indentifier can't use special symbols
#           ^
# SyntaxError: invalid syntax

# %%
import = 125  # Keywords can't be used as identifiers
# Out:
#   File "/tmp/ipykernel_8108/1967470270.py", line 1
#     import = 125  # Keywords can't be used as identifiers
#            ^
# SyntaxError: invalid syntax

# %%
"""
Correct way of defining an identifier
(Identifiers can be a combination of letters in lowercase (a to z) or uppercase
"""

val2 = 10

# %%
val_ = 99

# %% [markdown]
# # Comments in **Python**

# %%
# Single line comment
val1 = 10

# %%
#Multiple
#line
#comment
val1 = 10

# %%
'''
Multiple
line
comment
'''
val1 = 10

# %%
"""
Multiple
line
comment
"""
val1 = 10

# %% [markdown]
# # **Statements**

# %%
p = 20  #Creates an integer object with value 20 and assigns the variable p to p
q = 20  # Create new reference q which will point to value 20. p & q will be poi
# Out:
# (20, int, '0xb1b408')
