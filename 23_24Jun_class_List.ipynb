# %% [markdown]
# <a href="https://colab.research.google.com/github/MR-SAMIR21/Data-Science/blob/main/23_24Jun_class_List.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **list Datastructure**

# %%
l = []
l
# Out:
# []

# %%
type(l)
# Out:
# list

# %%
print(type(l))
# Out:
# <class 'list'>

# %%
len(l)
# Out:
# 0

# %%
l.append(10)
l
# Out:
# [10]

# %%
l.append(20)
l.append(30)
l.append(40)
l.append(50)

# %%
l
# Out:
# [10, 20, 30, 40, 50]

# %%
len(l)
# Out:
# 5

# %%
l.append(10,20)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1433/1493051523.py in <cell line: 0>()
# ----> 1 l.append(10,20)
#
# TypeError: list.append() takes exactly one argument (2 given)

# %%
l

# %% [markdown]
# # **24 jun**

# %%
l

# %%
l[0]

# %%
l[0]= 100

# %%
l
# Out:
# [100, 20, 30, 40, 50]

# %%
l[-2] = -50

# %%
l
# Out:
# [100, 20, 30, -50, 50]

# %%
l1 = l.copy()

# %%
l1print(l)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1433/3491052127.py in <cell line: 0>()
# ----> 1 l1print(l)
#
# NameError: name 'l1print' is not defined

# %%
print(l)
print(l1)
# Out:
# [100, 20, 30, -50, 50]
# [100, 20, 30, -50, 50]

# %%
l == l1
# Out:
# True

# %%
id(l) == id(l1)
# Out:
# False

# %%
id(l) != id(l1)
# Out:
# True

# %%
l.count(20)
# Out:
# 1

# %%
l.append(20)

# %%
l
# Out:
# [100, 20, 30, -50, 50, 20]

# %%
l.count(20)
# Out:
# 2

# %%
l1
# Out:
# [100, 20, 30, -50, 50]

# %%
len(l1)
# Out:
# 5

# %%
l1
# Out:
# [100, 20, 30, -50, 50]

# %%
l1.clear()

# %%
l1
# Out:
# []

# %%
del l1

# %%
l1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1433/2585568370.py in <cell line: 0>()
# ----> 1 l1
#
# NameError: name 'l1' is not defined

# %%
l

# %%
l.append(10)
l.append(20)
l.append(30)
l.append(40)
l.append(50)

# %%
l

# %%
l2 = []

# %%
l2.append(9)
l2.append('nit')
l2.append(True)
l2.append(1+2j)
l2.append(9.3)

# %%
l2
# Out:
# [9, True, 9.3, 20, 25, 30, -50, 50, 20, 10, 20, 30]

# %%
print(l)
print(l2)
# Out:
# [100, 20, 30, -50, 50, 20]
# [9, True, 9.3, 20, 25, 30, -50, 50, 20, 10, 20, 30]

# %%
l.index(50)
# Out:
# 4

# %%
l.index(20)
# Out:
# 1

# %%
l2
# Out:
# [9, True, 9.3, 20, 25, 30, -50, 50, 20, 10, 20, 30]

# %%
l2[1]
# Out:
# True

# %%
l2[1][0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1433/89957000.py in <cell line: 0>()
# ----> 1 l2[1][0]
#
# TypeError: 'bool' object is not subscriptable

# %%
l2
# Out:
# [9, True, 9.3, 20, 25, 30, -50, 50, 20, 10, 20, 30]

# %%
print(l2[1])
# Out:
# True

# %%
print(l2[1][0])
print(l2[1][1])
print(l2[1][2])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1433/1047848300.py in <cell line: 0>()
# ----> 1 print(l2[1][0])
#       2 print(l2[1][1])
#       3 print(l2[1][2])
#
# TypeError: 'bool' object is not subscriptable

# %%
l

# %%
l[:]

# %%
l[3:]

# %%
l[:14]

# %%
l[0:8:3]
# Out:
# [100, -50]

# %%
l2
# Out:
# [9, True, 9.3, 20, 25, 30, -50, 50, 20, 10, 20, 30]

# %%
l2[1:6:2]
# Out:
# [True, 20, 30]

# %%
l
# Out:
# [100, 20, 30, -50, 50, 20]

# %%
l.insert(25,2)

# %%
l
# Out:
# [100, 20, 30, -50, 50, 20, 2]

# %%
l.insert(2,25)

# %%
l
# Out:
# [100, 20, 25, 30, -50, 50, 20, 2]

# %%
l.pop()
# Out:
# 2

# %%
l
# Out:
# [100, 20, 25, 30, -50, 50, 20]

# %%
l.pop()
# Out:
# 20

# %%
l.pop()
# Out:
# 50

# %%
l2
# Out:
# [9, True, 9.3, 20, 25, 30, -50, 50, 20, 10, 20, 30]

# %%
l2.pop(3)
# Out:
# 20

# %%
l2
# Out:
# [9, True, 9.3, 25, 30, -50, 50, 20, 10, 20, 30]

# %%
l2.remove('nit')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_1433/3865097482.py in <cell line: 0>()
# ----> 1 l2.remove('nit')
#
# ValueError: list.remove(x): x not in list

# %%
l2

# %% [markdown]
# # **25th List**

# %%
l

# %%
100 in l

# %%
1000 in l

# %%
for i in l:
  print(i)

# %%
for i in enumerate(l):
  print(i)

# %%
print(l)
print(l2)
# Out:
# [100, 20, 25, 30, -50]
# [9, True, 9.3, 25, 30, -50, 50, 20, 10, 20, 30]

# %%
l2.extend(l)

# %%
print(l2)
# Out:
# [9, True, 9.3, 25, 30, -50, 50, 20, 10, 20, 30, 100, 20, 25, 30, -50]

# %%
l
# Out:
# [100, 20, 25, 30, -50]

# %%
l.sort()

# %%
l
# Out:
# [-50, 20, 25, 30, 100]

# %%
l.sort(reverse=True)

# %%
l
# Out:
# [100, 30, 25, 20, -50]

# %%
l3 = [1, 2.3, 'nit', True]
l3
# Out:
# [1, 2.3, 'nit', True]

# %%
l3.sort()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1433/805862314.py in <cell line: 0>()
# ----> 1 l3.sort()
#
# TypeError: '<' not supported between instances of 'str' and 'float'

# %%
l4 = ['a', 'z', 'n', 'm']
l4
# Out:
# ['a', 'z', 'n', 'm']

# %%
l4.sort()

# %%
l4
# Out:
# ['a', 'm', 'n', 'z']

# %%
l4.reverse()

# %%
l4
# Out:
# ['z', 'n', 'm', 'a']

# %% [markdown]
# # **All / Any**

# %%
l
# Out:
# [100, 30, 25, 20, -50]

# %%
all(l)
# Out:
# True

# %%
any(l)
# Out:
# True

# %%
l.append(0)

# %%
l
# Out:
# [100, 30, 25, 20, -50, 0]

# %%
all(l)
# Out:
# False

# %%
any(l)
# Out:
# True

# %% [markdown]
# # **TUPLE**

# %%
t = ()
t
# Out:
# ()

# %%
type(t)
# Out:
# tuple

# %%
t1 = (10, 20, 30)
t1
# Out:
# (10, 20, 30)

# %%
sbi = ('alex' , 123456789, 'cizp456', 4567)
sbi
# Out:
# ('alex', 123456789, 'cizp456', 4567)

# %%
sbi[1]
# Out:
# 123456789

# %%
sbi[1] = 20
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1433/2275733794.py in <cell line: 0>()
# ----> 1 sbi[1] = 20
#
# TypeError: 'tuple' object does not support item assignment

# %%
t1
# Out:
# (10, 20, 30)

# %%
t1.count(10)
# Out:
# 1

# %%
t1.index(20)
# Out:
# 1

# %%
t1
# Out:
# (10, 20, 30)

# %%
for i in t1:
  print(i)
# Out:
# 10
# 20
# 30

# %%
for i in enumerate(t1):
  print(i)
# Out:
# (0, 10)
# (1, 20)
# (2, 30)

# %%
t1
# Out:
# (10, 20, 30)

# %%
t2 = t1*3

# %%
t2
# Out:
# (10, 20, 30, 10, 20, 30, 10, 20, 30)

# %%
t2[2:6]
# Out:
# (30, 10, 20, 30)

# %%
t2.remove(20)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_1433/3349288617.py in <cell line: 0>()
# ----> 1 t2.remove(20)
#
# AttributeError: 'tuple' object has no attribute 'remove'

# %%
#del t2
