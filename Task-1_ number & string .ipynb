# %%
9
# Out:
# 9

# %%
9 + 9
# Out:
# 18

# %%
9 - 9
# Out:
# 0

# %%
10 * 2
# Out:
# 20

# %%
10 / 2  # float division
# Out:
# 5.0

# %%
10 // 2
# Out:
# 5

# %%
3 * 2
# Out:
# 6

# %%
3 ** 2
# Out:
# 9

# %%
3 ** 3
# Out:
# 27

# %%
_
# Out:
# 27

# %%
9
# Out:
# 9

# %%
_
# Out:
# 9

# %%
_ + 3
# Out:
# 12

# %%
_ + 3
# Out:
# 15

# %%
_ -12
# Out:
# 3

# %%
3 + 6 * 4 - 2 - 1
# Out:
# 24

# %%
3 + 6 * 4 -( 2 - 1 )
# Out:
# 26

# %%
import math
math.pi
# Out:
# 3.141592653589793

# %%
math.ceil(9.4)
# Out:
# 10

# %%
math.floor(9.4)
# Out:
# 9

# %%
welcome to samir
# Out:
#   File "/tmp/ipykernel_489/3776278003.py", line 1
#     welcome to samir
#             ^
# SyntaxError: invalid syntax

# %%
'welcome to samir'
# Out:
# 'welcome to samir'

# %%
"welcome to samir"
# Out:
# 'welcome to samir'

# %%
''' welcome to samir '''
# Out:
# ' welcome to samir '

# %%
'welcome to
samir''
# Out:
#   File "/tmp/ipykernel_489/3495428561.py", line 1
#     'welcome to
#     ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
"welcome to
samir"
# Out:
#   File "/tmp/ipykernel_489/497135409.py", line 1
#     "welcome to
#     ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
'''welcome to
samir'''
# Out:
# 'welcome to \nsamir'

# %%
_
# Out:
# 'welcome to \nsamir'

# %%
s = 'hello'
s
# Out:
# 'hello'

# %%
s[0]
# Out:
# 'h'

# %%
s[1]
# Out:
# 'e'

# %%
s[2]
# Out:
# 'l'

# %%
s[10]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_489/1733316026.py in <cell line: 0>()
# ----> 1 s[10]
#
# IndexError: string index out of range
